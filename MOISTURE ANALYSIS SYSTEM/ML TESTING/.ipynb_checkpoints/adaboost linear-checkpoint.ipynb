# %%
import kaggle

dataset_path = 'r3trovision/soil-moisture-temp-and-nutritions'
kaggle.api.dataset_download_files(dataset_path,path="DATASET/", unzip=True,quiet=False)
# Out:
# Downloading soil-moisture-temp-and-nutritions.zip to DATASET
# 100%|██████████████████████████████████████████████████████████████████████████████| 7.65M/7.65M [00:40<00:00, 199kB/s]

# %%
import pandas as pd
from sklearn.ensemble import AdaBoostRegressor
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
import numpy as np

# %%
data = pd.read_csv("../DATASET/Plant_Parameters.csv")
print(data.dtypes)
# Out:
# pH             float64
# Soil EC        float64
# Phosphorus     float64
# Potassium      float64
# Urea           float64
# T.S.P          float64
# M.O.P          float64
# Moisture       float64
# Temperature    float64
# Plant Type      object
# dtype: object

# %%
target = data['Moisture']  # Or specific target variable as needed
features = data.drop('Moisture',axis = 1)

# %%
le = LabelEncoder()
features['Plant Type'] = le.fit_transform(np.ravel(features['Plant Type']))

# %%
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
base_model = LinearRegression()
model = AdaBoostRegressor(n_estimators=100, estimator = base_model, learning_rate=1)
model.fit(X_train, y_train)
# Out:
# AdaBoostRegressor(estimator=LinearRegression(), learning_rate=1,
#                   n_estimators=100)

# %%
predictions = model.predict(X_test)
mse = mean_squared_error(y_test, predictions)
r2 = r2_score(y_test, predictions)

print("Mean Squared Error:", mse)
print("R-squared:", r2)

# Optionally plot predictions vs. actual values
plt.figure()
plt.scatter(y_test, predictions)
plt.xlabel("Actual Moisture")
plt.ylabel("Predicted Moisture")
plt.title("Random Forest Model Predictions")
plt.show()
# Out:
# Mean Squared Error: 54.02882058039261
# R-squared: 0.13250590213655944

# %%
importances = model.feature_importances_
feature_names = features.columns

for i, name in enumerate(feature_names):
    print(f"{name}: {importances[i]:.4f}")

# Optionally plot feature importances
plt.figure()
plt.bar(feature_names, importances)
plt.xlabel("Feature")
plt.ylabel("Importance")
plt.title("Feature Importance in Random Forest Model")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:294, in BaseWeightBoosting.feature_importances_(self)
#     292     norm = self.estimator_weights_.sum()
#     293     return (
# --> 294         sum(
#     295             weight * clf.feature_importances_
#     296             for weight, clf in zip(self.estimator_weights_, self.estimators_)
#     297         )
#     298         / norm
#     299     )
#     301 except AttributeError as e:
#
# File ~\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:295, in <genexpr>(.0)
#     292     norm = self.estimator_weights_.sum()
#     293     return (
#     294         sum(
# --> 295             weight * clf.feature_importances_
#     296             for weight, clf in zip(self.estimator_weights_, self.estimators_)
#     297         )
#     298         / norm
#     299     )
#     301 except AttributeError as e:
#
# AttributeError: 'LinearRegression' object has no attribute 'feature_importances_'
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 importances = model.feature_importances_
#       2 feature_names = features.columns
#       4 for i, name in enumerate(feature_names):
#
# File ~\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:302, in BaseWeightBoosting.feature_importances_(self)
#     293     return (
#     294         sum(
#     295             weight * clf.feature_importances_
#    (...)
#     298         / norm
#     299     )
#     301 except AttributeError as e:
# --> 302     raise AttributeError(
#     303         "Unable to compute feature importances "
#     304         "since estimator does not have a "
#     305         "feature_importances_ attribute"
#     306     ) from e
#
# AttributeError: Unable to compute feature importances since estimator does not have a feature_importances_ attribute
