# %%
import kaggle

dataset_path = 'r3trovision/soil-moisture-temp-and-nutritions'
kaggle.api.dataset_download_files(dataset_path,path="DATASET/", unzip=True,quiet=False)
# Out:
# Downloading soil-moisture-temp-and-nutritions.zip to DATASET
# 100%|██████████████████████████████████████████████████████████████████████████████| 7.65M/7.65M [00:40<00:00, 199kB/s]

# %%
import pandas as pd
from sklearn.ensemble import AdaBoostRegressor
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
import numpy as np

# %%
data = pd.read_csv("../DATASET/Plant_Parameters.csv")
print(data.dtypes)
# Out:
# pH             float64
# Soil EC        float64
# Phosphorus     float64
# Potassium      float64
# Urea           float64
# T.S.P          float64
# M.O.P          float64
# Moisture       float64
# Temperature    float64
# Plant Type      object
# dtype: object

# %%
target = data['Moisture']  # Or specific target variable as needed
features = data.drop('Moisture',axis = 1)

# %%
le = LabelEncoder()
features['Plant Type'] = le.fit_transform(np.ravel(features['Plant Type']))

# %%
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2)

# %%
from sklearn.linear_model import Ridge
from sklearn.ensemble import AdaBoostRegressor

# Create base Ridge regression model
base_model = Ridge()

# Create AdaBoostRegressor with Ridge as estimator
model = AdaBoostRegressor(base_model, n_estimators=100, learning_rate=1)

# Train the model
model.fit(X_train, y_train)

# Make predictions
predictions = model.predict(X_test)

# %%
predictions = model.predict(X_test)
mse = mean_squared_error(y_test, predictions)
r2 = r2_score(y_test, predictions)

print("Mean Squared Error:", mse)
print("R-squared:", r2)

# Optionally plot predictions vs. actual values
plt.figure()
plt.scatter(y_test, predictions)
plt.xlabel("Actual Moisture")
plt.ylabel("Predicted Moisture")
plt.title("Random Forest Model Predictions")
plt.show()
# Out:
# Mean Squared Error: 53.000904615349604
# R-squared: 0.12475400731322739

# %%
importances = model.feature_importances_
feature_names = features.columns

for i, name in enumerate(feature_names):
    print(f"{name}: {importances[i]:.4f}")

# Optionally plot feature importances
plt.figure()
plt.bar(feature_names, importances)
plt.xlabel("Feature")
plt.ylabel("Importance")
plt.title("Feature Importance in Random Forest Model")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\anaconda3\envs\gpu\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:303, in BaseWeightBoosting.feature_importances_(self)
#     301     norm = self.estimator_weights_.sum()
#     302     return (
# --> 303         sum(
#     304             weight * clf.feature_importances_
#     305             for weight, clf in zip(self.estimator_weights_, self.estimators_)
#     306         )
#     307         / norm
#     308     )
#     310 except AttributeError as e:
#
# File ~\anaconda3\envs\gpu\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:304, in <genexpr>(.0)
#     301     norm = self.estimator_weights_.sum()
#     302     return (
#     303         sum(
# --> 304             weight * clf.feature_importances_
#     305             for weight, clf in zip(self.estimator_weights_, self.estimators_)
#     306         )
#     307         / norm
#     308     )
#     310 except AttributeError as e:
#
# AttributeError: 'Ridge' object has no attribute 'feature_importances_'
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 importances = model.feature_importances_
#       2 feature_names = features.columns
#       4 for i, name in enumerate(feature_names):
#
# File ~\anaconda3\envs\gpu\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:311, in BaseWeightBoosting.feature_importances_(self)
#     302     return (
#     303         sum(
#     304             weight * clf.feature_importances_
#    (...)
#     307         / norm
#     308     )
#     310 except AttributeError as e:
# --> 311     raise AttributeError(
#     312         "Unable to compute feature importances "
#     313         "since estimator does not have a "
#     314         "feature_importances_ attribute"
#     315     ) from e
#
# AttributeError: Unable to compute feature importances since estimator does not have a feature_importances_ attribute
